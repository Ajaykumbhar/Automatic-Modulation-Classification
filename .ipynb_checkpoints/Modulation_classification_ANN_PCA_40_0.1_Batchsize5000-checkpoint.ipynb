# %%
#decompress the .bz2 file into .tar file
import sys
import os
import bz2

zipfile = bz2.BZ2File("./RML2016.10a.tar.bz2") # open the file
data = zipfile.read() # get the decompressed data

# %%
#write the .tar file
open('./RML2016.10a.tar', 'wb').write(data) # write a uncompressed file
# Out:
# 640952320

# %%
#extract the .tar file
import tarfile
my_tar = tarfile.open('./RML2016.10a.tar')
my_tar.extractall('./RadioML_data') # specify which folder to extract to
my_tar.close()

# %%
#extract the pickle file
import pickle
import numpy as np
Xd = pickle.load(open("./RadioML_data/RML2016.10a_dict.pkl",'rb'),encoding="bytes")
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []  
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod,snr)])
        for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))
X = np.vstack(X)

# %%
# Import all the things we need ---
# %matplotlib inline
import random
import tensorflow.keras.utils
import tensorflow.keras.models as models
from tensorflow.keras.layers import Reshape,Dense,Dropout,Activation,Flatten,LayerNormalization
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.regularizers import *
from tensorflow.keras.optimizers import *
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.keras

# %%
# Partition the data
#  into training and test sets of the form we can train/test on 
np.random.seed(2020)
n_examples = X.shape[0]
n_train = n_examples // 2
train_idx = np.random.choice(range(0,n_examples), size=n_train, replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = X[train_idx]
X_test =  X[test_idx]
#len(train_idx)

# %%
#one-hot encoding the label
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(np.asarray(lbl)[:,0])
print(lb.classes_)
lbl_encoded=lb.transform(np.asarray(lbl)[:,0])
y_train=lbl_encoded[train_idx]
y_test=lbl_encoded[test_idx]
# Out:
# [b'8PSK' b'AM-DSB' b'AM-SSB' b'BPSK' b'CPFSK' b'GFSK' b'PAM4' b'QAM16'
#  b'QAM64' b'QPSK' b'WBFM']

# %%
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
classes = mods
# Out:
# (110000, 2, 128) [2, 128]

# %%
#Number of dimensions after PCA = n_components
# Reference: https://github.com/dl4amc/source
pca = PCA(n_components= 40)

# %%
# PCA
X_train = X_train.transpose((1, 0, 2))
X_train = np.append(X_train[0], X_train[1], axis=1)
pca_apply = pca.fit(X_train)
print('Shape of X_train before aaplying PCA', np.shape(X_train))
X_train = pca_apply.transform(X_train)
print('Shape of X_train after applying PCA', np.shape(X_train))
#print(len(X_train[1]))
X_test = X_test.transpose((1, 0, 2))
X_test = np.append(X_test[0], X_test[1], axis=1)
X_test = pca_apply.transform(X_test)
X_train = np.stack((X_train[:, :len(X_train[0])//2], X_train[:,len(X_train[0])//2:]), axis=1)
X_test = np.stack((X_test[:, :len(X_test[0])//2], X_test[:, len(X_test[0])//2:]), axis=1)
print('Final shape of X_train', np.shape(X_train))
print('Final shape of X_test', np.shape(X_test))
# Out:
# Shape of X_train before aaplying PCA (110000, 256)
# Shape of X_train after applying PCA (110000, 40)
# Final shape of X_train (110000, 2, 20)
# Final shape of X_test (110000, 2, 20)

# %%
pca_in_shp = list(X_train.shape[1:])
print(X_train.shape,pca_in_shp)
# Out:
# (110000, 2, 20) [2, 20]

# %%
dr = 0.1 # dropout rate (%)
model = models.Sequential()
model.add(Reshape([1]+pca_in_shp, input_shape=pca_in_shp))
model.add(Flatten())
model.add(LayerNormalization(axis=1 , center=True , scale=True))
model.add(Dense(500, activation='relu', name="dense1"))
model.add(Dropout(dr))
model.add(Dense(200, activation='relu', name="dense2"))
model.add(Dropout(dr))
model.add(Dense(40, activation='relu', name="dense3"))
model.add(Dropout(dr))
model.add(Dense(11, activation='softmax'))
model.add(Reshape([len(classes)]))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 1, 2, 20)          0
#
#  flatten (Flatten)           (None, 40)                0
#
#  layer_normalization (LayerN  (None, 40)               80
#  ormalization)
#
#  dense1 (Dense)              (None, 500)               20500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense2 (Dense)              (None, 200)               100200
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense3 (Dense)              (None, 40)                8040
#
#  dropout_2 (Dropout)         (None, 40)                0
#
#  dense (Dense)               (None, 11)                451
#
#  reshape_1 (Reshape)         (None, 11)                0
#
# =================================================================
# Total params: 129,271
# Trainable params: 129,271
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set up some params 
nb_epoch = 100     # number of epochs to train on
batch_size = 5000  # training batch size

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

# %%
# perform training ...
#   - call the main training loop in keras for our network+dataset
filepath = 'ANN_0.1_PCA_40.wts.h5'
import time
t_0=time.time()

history = model.fit(X_train,
    y_train,
    batch_size=batch_size,
    epochs=nb_epoch,
    verbose=2,
    validation_data=(X_valid, y_valid),
    callbacks = [
        tensorflow.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, mode='auto'),
        tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')
    ])
delta_t=time.time()-t_0
print(delta_t)
# we re-load the best weights once training is finished
model.load_weights(filepath)
# Out:
# Epoch 1/100
# 18/18 - 2s - loss: 2.3170 - accuracy: 0.1479 - val_loss: 2.1849 - val_accuracy: 0.1875 - 2s/epoch - 134ms/step
# Epoch 2/100
# 18/18 - 1s - loss: 2.1384 - accuracy: 0.1901 - val_loss: 2.0351 - val_accuracy: 0.2581 - 1s/epoch - 67ms/step
# Epoch 3/100
# 18/18 - 1s - loss: 2.0037 - accuracy: 0.2574 - val_loss: 1.8825 - val_accuracy: 0.3179 - 1s/epoch - 67ms/step
# Epoch 4/100
# 18/18 - 1s - loss: 1.8801 - accuracy: 0.2996 - val_loss: 1.7903 - val_accuracy: 0.3425 - 1s/epoch - 66ms/step
# Epoch 5/100
# 18/18 - 1s - loss: 1.8074 - accuracy: 0.3278 - val_loss: 1.7470 - val_accuracy: 0.3551 - 1s/epoch - 66ms/step
# Epoch 6/100
# 18/18 - 1s - loss: 1.7608 - accuracy: 0.3442 - val_loss: 1.7125 - val_accuracy: 0.3538 - 1s/epoch - 66ms/step
# Epoch 7/100
# 18/18 - 1s - loss: 1.7229 - accuracy: 0.3521 - val_loss: 1.6856 - val_accuracy: 0.3645 - 1s/epoch - 67ms/step
# Epoch 8/100
# 18/18 - 1s - loss: 1.6926 - accuracy: 0.3628 - val_loss: 1.6628 - val_accuracy: 0.3685 - 1s/epoch - 67ms/step
# Epoch 9/100
# 18/18 - 1s - loss: 1.6683 - accuracy: 0.3680 - val_loss: 1.6420 - val_accuracy: 0.3728 - 1s/epoch - 67ms/step
# Epoch 10/100
# 18/18 - 1s - loss: 1.6466 - accuracy: 0.3735 - val_loss: 1.6241 - val_accuracy: 0.3827 - 1s/epoch - 66ms/step
# Epoch 11/100
# 18/18 - 1s - loss: 1.6251 - accuracy: 0.3813 - val_loss: 1.6062 - val_accuracy: 0.3890 - 1s/epoch - 68ms/step
# Epoch 12/100
# 18/18 - 1s - loss: 1.6098 - accuracy: 0.3859 - val_loss: 1.5937 - val_accuracy: 0.3904 - 1s/epoch - 72ms/step
# Epoch 13/100
# 18/18 - 1s - loss: 1.5925 - accuracy: 0.3910 - val_loss: 1.5820 - val_accuracy: 0.3954 - 1s/epoch - 75ms/step
# Epoch 14/100
# 18/18 - 1s - loss: 1.5829 - accuracy: 0.3932 - val_loss: 1.5755 - val_accuracy: 0.3951 - 1s/epoch - 70ms/step
# Epoch 15/100
# 18/18 - 1s - loss: 1.5721 - accuracy: 0.3976 - val_loss: 1.5670 - val_accuracy: 0.3982 - 1s/epoch - 66ms/step
# Epoch 16/100
# 18/18 - 1s - loss: 1.5631 - accuracy: 0.3997 - val_loss: 1.5619 - val_accuracy: 0.3987 - 1s/epoch - 69ms/step
# Epoch 17/100
# 18/18 - 1s - loss: 1.5567 - accuracy: 0.4017 - val_loss: 1.5572 - val_accuracy: 0.4000 - 1s/epoch - 68ms/step
# Epoch 18/100
# 18/18 - 1s - loss: 1.5484 - accuracy: 0.4055 - val_loss: 1.5536 - val_accuracy: 0.3990 - 1s/epoch - 72ms/step
# Epoch 19/100
# 18/18 - 1s - loss: 1.5410 - accuracy: 0.4065 - val_loss: 1.5496 - val_accuracy: 0.4020 - 1s/epoch - 69ms/step
# Epoch 20/100
# 18/18 - 1s - loss: 1.5358 - accuracy: 0.4067 - val_loss: 1.5461 - val_accuracy: 0.4010 - 1s/epoch - 66ms/step
# Epoch 21/100
# 18/18 - 1s - loss: 1.5305 - accuracy: 0.4102 - val_loss: 1.5410 - val_accuracy: 0.4025 - 1s/epoch - 68ms/step
# Epoch 22/100
# 18/18 - 1s - loss: 1.5228 - accuracy: 0.4111 - val_loss: 1.5372 - val_accuracy: 0.4027 - 1s/epoch - 66ms/step
# Epoch 23/100
# 18/18 - 1s - loss: 1.5149 - accuracy: 0.4147 - val_loss: 1.5278 - val_accuracy: 0.4043 - 1s/epoch - 67ms/step
# Epoch 24/100
# 18/18 - 1s - loss: 1.5025 - accuracy: 0.4170 - val_loss: 1.5155 - val_accuracy: 0.4059 - 1s/epoch - 67ms/step
# Epoch 25/100
# 18/18 - 1s - loss: 1.4931 - accuracy: 0.4211 - val_loss: 1.5073 - val_accuracy: 0.4091 - 1s/epoch - 66ms/step
# Epoch 26/100
# 18/18 - 1s - loss: 1.4808 - accuracy: 0.4227 - val_loss: 1.4873 - val_accuracy: 0.4137 - 1s/epoch - 65ms/step
# Epoch 27/100
# 18/18 - 1s - loss: 1.4665 - accuracy: 0.4268 - val_loss: 1.4757 - val_accuracy: 0.4182 - 1s/epoch - 65ms/step
# Epoch 28/100
# 18/18 - 1s - loss: 1.4561 - accuracy: 0.4311 - val_loss: 1.4669 - val_accuracy: 0.4203 - 1s/epoch - 67ms/step
# Epoch 29/100
# 18/18 - 1s - loss: 1.4486 - accuracy: 0.4326 - val_loss: 1.4629 - val_accuracy: 0.4217 - 1s/epoch - 68ms/step
# Epoch 30/100
# 18/18 - 1s - loss: 1.4439 - accuracy: 0.4322 - val_loss: 1.4580 - val_accuracy: 0.4239 - 1s/epoch - 67ms/step
# Epoch 31/100
# 18/18 - 1s - loss: 1.4364 - accuracy: 0.4373 - val_loss: 1.4549 - val_accuracy: 0.4258 - 1s/epoch - 65ms/step
# Epoch 32/100
# 18/18 - 1s - loss: 1.4313 - accuracy: 0.4360 - val_loss: 1.4535 - val_accuracy: 0.4241 - 1s/epoch - 67ms/step
# Epoch 33/100
# 18/18 - 1s - loss: 1.4269 - accuracy: 0.4370 - val_loss: 1.4504 - val_accuracy: 0.4224 - 1s/epoch - 65ms/step
# Epoch 34/100
# 18/18 - 1s - loss: 1.4232 - accuracy: 0.4401 - val_loss: 1.4483 - val_accuracy: 0.4242 - 1s/epoch - 69ms/step
# Epoch 35/100
# 18/18 - 1s - loss: 1.4191 - accuracy: 0.4404 - val_loss: 1.4467 - val_accuracy: 0.4247 - 1s/epoch - 67ms/step
# Epoch 36/100
# 18/18 - 1s - loss: 1.4155 - accuracy: 0.4437 - val_loss: 1.4454 - val_accuracy: 0.4241 - 1s/epoch - 66ms/step
# Epoch 37/100
# 18/18 - 1s - loss: 1.4111 - accuracy: 0.4427 - val_loss: 1.4466 - val_accuracy: 0.4245 - 1s/epoch - 65ms/step
# Epoch 38/100
# 18/18 - 1s - loss: 1.4089 - accuracy: 0.4454 - val_loss: 1.4448 - val_accuracy: 0.4234 - 1s/epoch - 67ms/step
# Epoch 39/100
# 18/18 - 1s - loss: 1.4062 - accuracy: 0.4469 - val_loss: 1.4428 - val_accuracy: 0.4253 - 1s/epoch - 67ms/step
# Epoch 40/100
# 18/18 - 1s - loss: 1.4014 - accuracy: 0.4476 - val_loss: 1.4420 - val_accuracy: 0.4250 - 1s/epoch - 67ms/step
# Epoch 41/100
# 18/18 - 1s - loss: 1.3986 - accuracy: 0.4479 - val_loss: 1.4432 - val_accuracy: 0.4251 - 1s/epoch - 64ms/step
# Epoch 42/100
# 18/18 - 1s - loss: 1.3967 - accuracy: 0.4489 - val_loss: 1.4420 - val_accuracy: 0.4265 - 1s/epoch - 65ms/step
# Epoch 43/100
# 18/18 - 1s - loss: 1.3929 - accuracy: 0.4510 - val_loss: 1.4420 - val_accuracy: 0.4252 - 1s/epoch - 65ms/step
# Epoch 44/100
# 18/18 - 1s - loss: 1.3908 - accuracy: 0.4521 - val_loss: 1.4399 - val_accuracy: 0.4255 - 1s/epoch - 66ms/step
# Epoch 45/100
# 18/18 - 1s - loss: 1.3873 - accuracy: 0.4526 - val_loss: 1.4417 - val_accuracy: 0.4264 - 1s/epoch - 65ms/step
# Epoch 46/100
# 18/18 - 1s - loss: 1.3839 - accuracy: 0.4548 - val_loss: 1.4412 - val_accuracy: 0.4238 - 1s/epoch - 65ms/step
# Epoch 47/100
# 18/18 - 1s - loss: 1.3820 - accuracy: 0.4550 - val_loss: 1.4401 - val_accuracy: 0.4257 - 1s/epoch - 65ms/step
# Epoch 48/100
# 18/18 - 1s - loss: 1.3778 - accuracy: 0.4568 - val_loss: 1.4393 - val_accuracy: 0.4253 - 1s/epoch - 66ms/step
# Epoch 49/100
# 18/18 - 1s - loss: 1.3754 - accuracy: 0.4588 - val_loss: 1.4391 - val_accuracy: 0.4275 - 1s/epoch - 66ms/step
# Epoch 50/100
# 18/18 - 1s - loss: 1.3740 - accuracy: 0.4595 - val_loss: 1.4404 - val_accuracy: 0.4252 - 1s/epoch - 67ms/step
# Epoch 51/100
# 18/18 - 1s - loss: 1.3699 - accuracy: 0.4598 - val_loss: 1.4395 - val_accuracy: 0.4254 - 1s/epoch - 66ms/step
# Epoch 52/100
# 18/18 - 1s - loss: 1.3680 - accuracy: 0.4606 - val_loss: 1.4383 - val_accuracy: 0.4286 - 1s/epoch - 66ms/step
# Epoch 53/100
# 18/18 - 1s - loss: 1.3648 - accuracy: 0.4644 - val_loss: 1.4385 - val_accuracy: 0.4250 - 1s/epoch - 65ms/step
# Epoch 54/100
# 18/18 - 1s - loss: 1.3617 - accuracy: 0.4636 - val_loss: 1.4405 - val_accuracy: 0.4251 - 1s/epoch - 65ms/step
# Epoch 55/100
# 18/18 - 1s - loss: 1.3592 - accuracy: 0.4635 - val_loss: 1.4379 - val_accuracy: 0.4249 - 1s/epoch - 67ms/step
# Epoch 56/100
# 18/18 - 1s - loss: 1.3560 - accuracy: 0.4681 - val_loss: 1.4399 - val_accuracy: 0.4243 - 1s/epoch - 65ms/step
# Epoch 57/100
# 18/18 - 1s - loss: 1.3540 - accuracy: 0.4664 - val_loss: 1.4371 - val_accuracy: 0.4260 - 1s/epoch - 65ms/step
# Epoch 58/100
# 18/18 - 1s - loss: 1.3529 - accuracy: 0.4667 - val_loss: 1.4379 - val_accuracy: 0.4265 - 1s/epoch - 64ms/step
# Epoch 59/100
# 18/18 - 1s - loss: 1.3512 - accuracy: 0.4680 - val_loss: 1.4409 - val_accuracy: 0.4258 - 1s/epoch - 65ms/step
# Epoch 60/100
# 18/18 - 1s - loss: 1.3475 - accuracy: 0.4698 - val_loss: 1.4379 - val_accuracy: 0.4276 - 1s/epoch - 65ms/step
# Epoch 61/100
# 18/18 - 1s - loss: 1.3466 - accuracy: 0.4705 - val_loss: 1.4381 - val_accuracy: 0.4274 - 1s/epoch - 66ms/step
# Epoch 62/100
# 18/18 - 1s - loss: 1.3429 - accuracy: 0.4719 - val_loss: 1.4384 - val_accuracy: 0.4278 - 1s/epoch - 66ms/step
# 76.01201891899109

# %%
# Show simple version of performance
score1 = model.evaluate(X_train, y_train, verbose=0, batch_size=batch_size)
score2 = model.evaluate(X_valid, y_valid, verbose=0, batch_size=batch_size)
score3 = model.evaluate(X_test, y_test, verbose=0, batch_size=batch_size)
print(score1)
print(score2)
print(score3)
# Out:
# [1.291517972946167, 0.4987272620201111]
# [1.4370557069778442, 0.42595455050468445]
# [1.4365980625152588, 0.42968180775642395]

# %%
# Show loss curves 
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Plot confusion matrix
test_Y_hat = model.predict(X_test, batch_size=batch_size)
conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])
for i in range(0,X_test.shape[0]):
    j = list(y_test[i,:]).index(1)
    k = int(np.argmax(test_Y_hat[i,:]))
    conf[j,k] = conf[j,k] + 1
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
plot_confusion_matrix(confnorm, labels=classes)
# Out:
# 22/22 [==============================] - 0s 14ms/step

# %%
# Get the test accuracy for different SNRs
acc = {}
acc_array=[]

snr_array=np.asarray(lbl)[:,1]
lb_temp = preprocessing.LabelBinarizer()
lb_temp.fit(snr_array)
temp_array=lb_temp.classes_
snr_label_array = []


snr_label_array.append(temp_array[6])
snr_label_array.append(temp_array[4])
snr_label_array.append(temp_array[3])
snr_label_array.append(temp_array[2])
snr_label_array.append(temp_array[1])
snr_label_array.append(temp_array[0])
snr_label_array.append(temp_array[9])
snr_label_array.append(temp_array[8])
snr_label_array.append(temp_array[7])
snr_label_array.append(temp_array[5])
snr_label_array.append(temp_array[10])
snr_label_array.append(temp_array[16])
snr_label_array.append(temp_array[17])
snr_label_array.append(temp_array[18])
snr_label_array.append(temp_array[19])
snr_label_array.append(temp_array[11])
snr_label_array.append(temp_array[12])
snr_label_array.append(temp_array[13])
snr_label_array.append(temp_array[14])
snr_label_array.append(temp_array[15])

#print(snr_label_array)
y_test_snr=snr_array[test_idx]



for snr in snr_label_array:
    test_X_i = X_test[np.where(y_test_snr==snr)]
    test_Y_i = y_test[np.where(y_test_snr==snr)]
    
    test_Y_i_hat = model.predict(test_X_i)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,test_X_i.shape[0]):
        j = list(test_Y_i[i,:]).index(1)
        k = int(np.argmax(test_Y_i_hat[i,:]))
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
    
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix"%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print("Overall Accuracy: ", cor / (cor+ncor),"for SNR",snr)
    acc[snr] = 1.0*cor/(cor+ncor)
    acc_array.append(1.0*cor/(cor+ncor))

print("Random Guess Accuracy:",1/11)
# Out:
# 174/174 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.09536637931034483 for SNR b'-20'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.10056579667822596 for SNR b'-18'
# 174/174 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.0991705733862243 for SNR b'-16'
# 171/171 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.10424286759326994 for SNR b'-14'
# 175/175 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.12993744414655942 for SNR b'-12'
# 170/170 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.20121390472687142 for SNR b'-10'
# 169/169 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.30972633136094674 for SNR b'-8'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.4679334916864608 for SNR b'-6'
# 175/175 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5914306202940122 for SNR b'-4'
# 173/173 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.6285403050108932 for SNR b'-2'
# 171/171 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.6073134876883499 for SNR b'0'
# 173/173 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5985123367198839 for SNR b'2'
# 171/171 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5892040256175664 for SNR b'4'
# 171/171 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5914511098880939 for SNR b'6'
# 174/174 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5688601222581805 for SNR b'8'
# 176/176 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5864032746040221 for SNR b'10'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.576187875477881 for SNR b'12'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5856232939035487 for SNR b'14'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5812215132178669 for SNR b'16'
# 170/170 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5847488921713442 for SNR b'18'
# Random Guess Accuracy: 0.09090909090909091

# %%
print(acc_array)
# Out:
# [0.09536637931034483, 0.10056579667822596, 0.0991705733862243, 0.10424286759326994, 0.12993744414655942, 0.20121390472687142, 0.30972633136094674, 0.4679334916864608, 0.5914306202940122, 0.6285403050108932, 0.6073134876883499, 0.5985123367198839, 0.5892040256175664, 0.5914511098880939, 0.5688601222581805, 0.5864032746040221, 0.576187875477881, 0.5856232939035487, 0.5812215132178669, 0.5847488921713442]

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), acc_array)

# %%
dr_01 = [0.09375, 0.1007483117357182, 0.09826902271907681, 0.10515727871250914, 0.12672028596961574, 0.19385690638219608, 0.308801775147929, 0.4735976612461173, 0.5937612047328792, 0.6309005083514887, 0.6054759279676589, 0.6081277213352685, 0.5919487648673376, 0.5934690882406898, 0.5807263574253866, 0.588716853532657, 0.5841980702712544, 0.5954504094631483, 0.5874202370100273, 0.5941654357459379];
dr_04 = [0.09123563218390805, 0.09709801058587333, 0.09790840245221781, 0.1005852231163131, 0.13315460232350312, 0.22788302372631966, 0.33154585798816566, 0.517266581399598, 0.6149157404087486, 0.5780682643427741, 0.5733186328555678, 0.5767416545718432, 0.5657822506861848, 0.5753072830673271, 0.5586120100683207, 0.5588182950702972, 0.558529036956126, 0.575614194722475, 0.5668185961713765, 0.5795790251107829];
dr_06 = [0.09141522988505747, 0.09928819127578026, 0.09610530111792283, 0.1005852231163131, 0.12707774798927615, 0.21519220158175464, 0.30196005917159763, 0.47030878859857483, 0.57529580494801, 0.5375816993464052, 0.543917677324513, 0.5435413642960812, 0.5313815187557182, 0.5411851036507063, 0.5275080906148867, 0.5278519309485674, 0.5224831603859458, 0.5408553230209281, 0.5358249772105743, 0.5415435745937962];

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), dr_01,label = 'dropout = 0.1')
plt.plot(np.arange(-20,20,2),dr_04,label = 'dropout = 0.4')
plt.plot(np.arange(-20,20,2),dr_06,label = 'dropout = 0.6')
plt.legend(loc="upper left")

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), bs_256,label = 'Batch size = 256')
plt.plot(np.arange(-20,20,2),bs_1024,label = 'Batch size = 1024')
plt.plot(np.arange(-20,20,2),bs_5000,label = 'Batch size = 5000')
plt.legend(loc="upper left")
