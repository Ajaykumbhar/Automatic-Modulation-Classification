# %%
#decompress the .bz2 file into .tar file
import sys
import os
import bz2

zipfile = bz2.BZ2File("./RML2016.10a.tar.bz2") # open the file
data = zipfile.read() # get the decompressed data

# %%
#write the .tar file
open('./RML2016.10a.tar', 'wb').write(data) # write a uncompressed file
# Out:
# 640952320

# %%
#extract the .tar file
import tarfile
my_tar = tarfile.open('./RML2016.10a.tar')
my_tar.extractall('./RadioML_data') # specify which folder to extract to
my_tar.close()

# %%
#extract the pickle file
import pickle
import numpy as np
Xd = pickle.load(open("./RadioML_data/RML2016.10a_dict.pkl",'rb'),encoding="bytes")
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []  
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod,snr)])
        for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))
X = np.vstack(X)

# %%
# Import all the things we need ---
# %matplotlib inline
import random
"""os.environ["KERAS_BACKEND"] = "theano"
#os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ["THEANO_FLAGS"]  = "device=gpu%d"%(1)
from keras.utils import multi_gpu_model
from keras import backend as K"""
import keras.models as models
import tensorflow.keras.utils
import tensorflow.keras.models as models
from tensorflow.keras.layers import Reshape,Dense,Dropout,Activation,Flatten
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.regularizers import *
from tensorflow.keras.optimizers import *
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.keras

# %%
# Partition the data
# into training and test sets of the form we can train/test on 
np.random.seed(2020)
n_examples = X.shape[0]
n_train = n_examples // 2
train_idx = np.random.choice(range(0,n_examples), size=n_train, replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = X[train_idx]
X_test =  X[test_idx]
print(X_test.shape)
# Out:
# (110000, 2, 128)

# %%
#one-hot encoding the label
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(np.asarray(lbl)[:,0])
print(lb.classes_)
lbl_encoded=lb.transform(np.asarray(lbl)[:,0])
y_train=lbl_encoded[train_idx]
y_test=lbl_encoded[test_idx]
# Out:
# [b'8PSK' b'AM-DSB' b'AM-SSB' b'BPSK' b'CPFSK' b'GFSK' b'PAM4' b'QAM16'
#  b'QAM64' b'QPSK' b'WBFM']

# %%
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
classes = mods
# Out:
# (110000, 2, 128) [2, 128]

# %%
#Number of dimensions after PCA = n_components
# Reference: https://github.com/dl4amc/source
pca = PCA(n_components= 220)

# %%
# PCA
X_train = X_train.transpose((1, 0, 2))
X_train = np.append(X_train[0], X_train[1], axis=1)
pca_apply = pca.fit(X_train)
print('Shape of X_train before aaplying PCA', np.shape(X_train))
X_train = pca_apply.transform(X_train)
print('Shape of X_train after applying PCA', np.shape(X_train))
#print(len(X_train[1]))
X_test = X_test.transpose((1, 0, 2))
X_test = np.append(X_test[0], X_test[1], axis=1)
X_test = pca_apply.transform(X_test)
X_train = np.stack((X_train[:, :len(X_train[0])//2], X_train[:,len(X_train[0])//2:]), axis=1)
X_test = np.stack((X_test[:, :len(X_test[0])//2], X_test[:, len(X_test[0])//2:]), axis=1)
print('Final shape of X_train', np.shape(X_train))
print('Final shape of X_test', np.shape(X_test))
#in_shp[1]=pca_dim
# Out:
# Shape of X_train before aaplying PCA (110000, 256)
# Shape of X_train after applying PCA (110000, 220)
# Final shape of X_train (110000, 2, 110)
# Final shape of X_test (110000, 2, 110)

# %%
pca_in_shp = list(X_train.shape[1:])
print(X_train.shape,pca_in_shp)
# Out:
# (110000, 2, 110) [2, 110]

# %%
dr = 0.1 # dropout rate (%)
model = models.Sequential()
model.add(Reshape([1]+pca_in_shp, input_shape=pca_in_shp))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(220,1, 1, activation="relu", name="conv1"))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(220,1, 1, activation="relu", name="conv2"))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(80,1, 1, activation="relu", name="conv3"))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(80,1, 1, activation="relu", name="conv4"))
model.add(Dropout(dr))
model.add(Flatten())
model.add(Dense(220,activation='relu', name="dense1"))
model.add(Dropout(dr))
model.add(Dense( len(classes),name="dense2" ))
model.add(Activation('softmax'))
model.add(Reshape([len(classes)]))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 1, 2, 110)         0
#
#  zero_padding2d (ZeroPadding  (None, 1, 6, 110)        0
#  2D)
#
#  conv1 (Conv2D)              (None, 1, 6, 220)         24420
#
#  dropout (Dropout)           (None, 1, 6, 220)         0
#
#  zero_padding2d_1 (ZeroPaddi  (None, 1, 10, 220)       0
#  ng2D)
#
#  conv2 (Conv2D)              (None, 1, 10, 220)        48620
#
#  dropout_1 (Dropout)         (None, 1, 10, 220)        0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 1, 14, 220)       0
#  ng2D)
#
#  conv3 (Conv2D)              (None, 1, 14, 80)         17680
#
#  dropout_2 (Dropout)         (None, 1, 14, 80)         0
#
#  zero_padding2d_3 (ZeroPaddi  (None, 1, 18, 80)        0
#  ng2D)
#
#  conv4 (Conv2D)              (None, 1, 18, 80)         6480
#
#  dropout_3 (Dropout)         (None, 1, 18, 80)         0
#
#  flatten (Flatten)           (None, 1440)              0
#
#  dense1 (Dense)              (None, 220)               317020
#
#  dropout_4 (Dropout)         (None, 220)               0
#
#  dense2 (Dense)              (None, 11)                2431
#
#  activation (Activation)     (None, 11)                0
#
#  reshape_1 (Reshape)         (None, 11)                0
#
# =================================================================
# Total params: 416,651
# Trainable params: 416,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set up some params 
nb_epoch = 100     # number of epochs to train on
batch_size = 5000  # training batch size

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

# %%
# perform training ...
#   - call the main training loop in keras for our network+dataset
filepath = 'convmodrecnets_CNN_220_0.1.wts.h5'

import time
t_0=time.time()

history = model.fit(X_train,
    y_train,
    batch_size=batch_size,
    epochs=nb_epoch,
    verbose=2,
    validation_data=(X_valid, y_valid),
    callbacks = [
        tensorflow.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, mode='auto'),
        tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')
    ])
delta_t=time.time()-t_0
print(delta_t)
# we re-load the best weights once training is finished
model.load_weights(filepath)
# Out:
# Epoch 1/100
# 18/18 - 12s - loss: 2.3912 - accuracy: 0.1322 - val_loss: 2.3605 - val_accuracy: 0.1746 - 12s/epoch - 690ms/step
# Epoch 2/100
# 18/18 - 10s - loss: 2.2765 - accuracy: 0.1500 - val_loss: 2.2082 - val_accuracy: 0.1523 - 10s/epoch - 582ms/step
# Epoch 3/100
# 18/18 - 10s - loss: 2.1578 - accuracy: 0.1909 - val_loss: 2.0637 - val_accuracy: 0.2212 - 10s/epoch - 568ms/step
# Epoch 4/100
# 18/18 - 10s - loss: 2.0427 - accuracy: 0.2240 - val_loss: 1.9859 - val_accuracy: 0.2607 - 10s/epoch - 546ms/step
# Epoch 5/100
# 18/18 - 10s - loss: 1.9755 - accuracy: 0.2493 - val_loss: 1.9176 - val_accuracy: 0.2734 - 10s/epoch - 543ms/step
# Epoch 6/100
# 18/18 - 10s - loss: 1.9183 - accuracy: 0.2700 - val_loss: 1.8673 - val_accuracy: 0.3095 - 10s/epoch - 555ms/step
# Epoch 7/100
# 18/18 - 10s - loss: 1.8769 - accuracy: 0.2855 - val_loss: 1.8377 - val_accuracy: 0.3067 - 10s/epoch - 560ms/step
# Epoch 8/100
# 18/18 - 10s - loss: 1.8525 - accuracy: 0.2939 - val_loss: 1.8170 - val_accuracy: 0.3216 - 10s/epoch - 548ms/step
# Epoch 9/100
# 18/18 - 10s - loss: 1.8344 - accuracy: 0.3008 - val_loss: 1.8189 - val_accuracy: 0.3140 - 10s/epoch - 543ms/step
# Epoch 10/100
# 18/18 - 10s - loss: 1.8131 - accuracy: 0.3095 - val_loss: 1.7891 - val_accuracy: 0.3310 - 10s/epoch - 566ms/step
# Epoch 11/100
# 18/18 - 10s - loss: 1.7968 - accuracy: 0.3145 - val_loss: 1.7784 - val_accuracy: 0.3286 - 10s/epoch - 536ms/step
# Epoch 12/100
# 18/18 - 10s - loss: 1.7844 - accuracy: 0.3184 - val_loss: 1.7785 - val_accuracy: 0.3286 - 10s/epoch - 539ms/step
# Epoch 13/100
# 18/18 - 10s - loss: 1.7736 - accuracy: 0.3219 - val_loss: 1.7613 - val_accuracy: 0.3370 - 10s/epoch - 562ms/step
# Epoch 14/100
# 18/18 - 10s - loss: 1.7621 - accuracy: 0.3261 - val_loss: 1.7526 - val_accuracy: 0.3385 - 10s/epoch - 581ms/step
# Epoch 15/100
# 18/18 - 10s - loss: 1.7519 - accuracy: 0.3310 - val_loss: 1.7466 - val_accuracy: 0.3414 - 10s/epoch - 555ms/step
# Epoch 16/100
# 18/18 - 10s - loss: 1.7454 - accuracy: 0.3310 - val_loss: 1.7474 - val_accuracy: 0.3404 - 10s/epoch - 540ms/step
# Epoch 17/100
# 18/18 - 10s - loss: 1.7364 - accuracy: 0.3368 - val_loss: 1.7453 - val_accuracy: 0.3356 - 10s/epoch - 542ms/step
# Epoch 18/100
# 18/18 - 10s - loss: 1.7354 - accuracy: 0.3351 - val_loss: 1.7362 - val_accuracy: 0.3376 - 10s/epoch - 541ms/step
# Epoch 19/100
# 18/18 - 10s - loss: 1.7245 - accuracy: 0.3383 - val_loss: 1.7306 - val_accuracy: 0.3466 - 10s/epoch - 546ms/step
# Epoch 20/100
# 18/18 - 10s - loss: 1.7178 - accuracy: 0.3413 - val_loss: 1.7218 - val_accuracy: 0.3488 - 10s/epoch - 545ms/step
# Epoch 21/100
# 18/18 - 10s - loss: 1.7134 - accuracy: 0.3445 - val_loss: 1.7242 - val_accuracy: 0.3471 - 10s/epoch - 536ms/step
# Epoch 22/100
# 18/18 - 10s - loss: 1.7055 - accuracy: 0.3463 - val_loss: 1.7179 - val_accuracy: 0.3505 - 10s/epoch - 560ms/step
# Epoch 23/100
# 18/18 - 10s - loss: 1.7000 - accuracy: 0.3489 - val_loss: 1.7152 - val_accuracy: 0.3496 - 10s/epoch - 562ms/step
# Epoch 24/100
# 18/18 - 10s - loss: 1.6934 - accuracy: 0.3513 - val_loss: 1.7193 - val_accuracy: 0.3484 - 10s/epoch - 541ms/step
# Epoch 25/100
# 18/18 - 10s - loss: 1.6938 - accuracy: 0.3512 - val_loss: 1.7097 - val_accuracy: 0.3537 - 10s/epoch - 570ms/step
# Epoch 26/100
# 18/18 - 10s - loss: 1.6836 - accuracy: 0.3550 - val_loss: 1.7082 - val_accuracy: 0.3509 - 10s/epoch - 550ms/step
# Epoch 27/100
# 18/18 - 10s - loss: 1.6785 - accuracy: 0.3546 - val_loss: 1.7059 - val_accuracy: 0.3482 - 10s/epoch - 579ms/step
# Epoch 28/100
# 18/18 - 10s - loss: 1.6737 - accuracy: 0.3577 - val_loss: 1.7002 - val_accuracy: 0.3558 - 10s/epoch - 572ms/step
# Epoch 29/100
# 18/18 - 10s - loss: 1.6661 - accuracy: 0.3611 - val_loss: 1.6938 - val_accuracy: 0.3578 - 10s/epoch - 577ms/step
# Epoch 30/100
# 18/18 - 10s - loss: 1.6610 - accuracy: 0.3608 - val_loss: 1.6979 - val_accuracy: 0.3542 - 10s/epoch - 554ms/step
# Epoch 31/100
# 18/18 - 10s - loss: 1.6592 - accuracy: 0.3633 - val_loss: 1.7127 - val_accuracy: 0.3479 - 10s/epoch - 553ms/step
# Epoch 32/100
# 18/18 - 10s - loss: 1.6548 - accuracy: 0.3611 - val_loss: 1.6904 - val_accuracy: 0.3547 - 10s/epoch - 545ms/step
# Epoch 33/100
# 18/18 - 10s - loss: 1.6438 - accuracy: 0.3663 - val_loss: 1.6871 - val_accuracy: 0.3592 - 10s/epoch - 541ms/step
# Epoch 34/100
# 18/18 - 10s - loss: 1.6395 - accuracy: 0.3678 - val_loss: 1.6827 - val_accuracy: 0.3600 - 10s/epoch - 544ms/step
# Epoch 35/100
# 18/18 - 10s - loss: 1.6328 - accuracy: 0.3708 - val_loss: 1.6802 - val_accuracy: 0.3606 - 10s/epoch - 541ms/step
# Epoch 36/100
# 18/18 - 10s - loss: 1.6279 - accuracy: 0.3707 - val_loss: 1.6765 - val_accuracy: 0.3613 - 10s/epoch - 572ms/step
# Epoch 37/100
# 18/18 - 11s - loss: 1.6255 - accuracy: 0.3709 - val_loss: 1.6785 - val_accuracy: 0.3630 - 11s/epoch - 595ms/step
# Epoch 38/100
# 18/18 - 10s - loss: 1.6200 - accuracy: 0.3745 - val_loss: 1.6712 - val_accuracy: 0.3605 - 10s/epoch - 555ms/step
# Epoch 39/100
# 18/18 - 10s - loss: 1.6168 - accuracy: 0.3750 - val_loss: 1.6641 - val_accuracy: 0.3610 - 10s/epoch - 548ms/step
# Epoch 40/100
# 18/18 - 10s - loss: 1.6105 - accuracy: 0.3768 - val_loss: 1.6657 - val_accuracy: 0.3624 - 10s/epoch - 567ms/step
# Epoch 41/100
# 18/18 - 10s - loss: 1.6050 - accuracy: 0.3783 - val_loss: 1.6718 - val_accuracy: 0.3611 - 10s/epoch - 543ms/step
# Epoch 42/100
# 18/18 - 10s - loss: 1.6065 - accuracy: 0.3786 - val_loss: 1.6640 - val_accuracy: 0.3664 - 10s/epoch - 552ms/step
# Epoch 43/100
# 18/18 - 10s - loss: 1.6005 - accuracy: 0.3801 - val_loss: 1.6707 - val_accuracy: 0.3643 - 10s/epoch - 543ms/step
# Epoch 44/100
# 18/18 - 10s - loss: 1.5997 - accuracy: 0.3820 - val_loss: 1.6650 - val_accuracy: 0.3615 - 10s/epoch - 558ms/step
# Epoch 45/100
# 18/18 - 10s - loss: 1.5933 - accuracy: 0.3828 - val_loss: 1.6539 - val_accuracy: 0.3683 - 10s/epoch - 560ms/step
# Epoch 46/100
# 18/18 - 10s - loss: 1.5863 - accuracy: 0.3850 - val_loss: 1.6542 - val_accuracy: 0.3701 - 10s/epoch - 563ms/step
# Epoch 47/100
# 18/18 - 10s - loss: 1.5799 - accuracy: 0.3877 - val_loss: 1.6503 - val_accuracy: 0.3690 - 10s/epoch - 556ms/step
# Epoch 48/100
# 18/18 - 10s - loss: 1.5746 - accuracy: 0.3906 - val_loss: 1.6478 - val_accuracy: 0.3755 - 10s/epoch - 561ms/step
# Epoch 49/100
# 18/18 - 10s - loss: 1.5701 - accuracy: 0.3909 - val_loss: 1.6443 - val_accuracy: 0.3717 - 10s/epoch - 550ms/step
# Epoch 50/100
# 18/18 - 11s - loss: 1.5678 - accuracy: 0.3913 - val_loss: 1.6345 - val_accuracy: 0.3773 - 11s/epoch - 589ms/step
# Epoch 51/100
# 18/18 - 10s - loss: 1.5624 - accuracy: 0.3939 - val_loss: 1.6334 - val_accuracy: 0.3713 - 10s/epoch - 574ms/step
# Epoch 52/100
# 18/18 - 10s - loss: 1.5573 - accuracy: 0.3943 - val_loss: 1.6341 - val_accuracy: 0.3778 - 10s/epoch - 553ms/step
# Epoch 53/100
# 18/18 - 10s - loss: 1.5559 - accuracy: 0.3969 - val_loss: 1.6301 - val_accuracy: 0.3774 - 10s/epoch - 551ms/step
# Epoch 54/100
# 18/18 - 10s - loss: 1.5505 - accuracy: 0.3991 - val_loss: 1.6352 - val_accuracy: 0.3800 - 10s/epoch - 538ms/step
# Epoch 55/100
# 18/18 - 10s - loss: 1.5455 - accuracy: 0.3992 - val_loss: 1.6259 - val_accuracy: 0.3802 - 10s/epoch - 540ms/step
# Epoch 56/100
# 18/18 - 10s - loss: 1.5444 - accuracy: 0.4013 - val_loss: 1.6229 - val_accuracy: 0.3783 - 10s/epoch - 538ms/step
# Epoch 57/100
# 18/18 - 10s - loss: 1.5448 - accuracy: 0.4014 - val_loss: 1.6238 - val_accuracy: 0.3801 - 10s/epoch - 530ms/step
# Epoch 58/100
# 18/18 - 10s - loss: 1.5378 - accuracy: 0.4031 - val_loss: 1.6203 - val_accuracy: 0.3812 - 10s/epoch - 564ms/step
# Epoch 59/100
# 18/18 - 10s - loss: 1.5403 - accuracy: 0.4026 - val_loss: 1.6257 - val_accuracy: 0.3806 - 10s/epoch - 543ms/step
# Epoch 60/100
# 18/18 - 10s - loss: 1.5359 - accuracy: 0.4034 - val_loss: 1.6204 - val_accuracy: 0.3833 - 10s/epoch - 558ms/step
# Epoch 61/100
# 18/18 - 10s - loss: 1.5319 - accuracy: 0.4066 - val_loss: 1.6203 - val_accuracy: 0.3837 - 10s/epoch - 577ms/step
# Epoch 62/100
# 18/18 - 10s - loss: 1.5254 - accuracy: 0.4076 - val_loss: 1.6163 - val_accuracy: 0.3834 - 10s/epoch - 568ms/step
# Epoch 63/100
# 18/18 - 10s - loss: 1.5194 - accuracy: 0.4100 - val_loss: 1.6174 - val_accuracy: 0.3845 - 10s/epoch - 549ms/step
# Epoch 64/100
# 18/18 - 10s - loss: 1.5184 - accuracy: 0.4103 - val_loss: 1.6176 - val_accuracy: 0.3853 - 10s/epoch - 549ms/step
# Epoch 65/100
# 18/18 - 10s - loss: 1.5142 - accuracy: 0.4095 - val_loss: 1.6174 - val_accuracy: 0.3829 - 10s/epoch - 558ms/step
# Epoch 66/100
# 18/18 - 10s - loss: 1.5143 - accuracy: 0.4102 - val_loss: 1.6157 - val_accuracy: 0.3850 - 10s/epoch - 544ms/step
# Epoch 67/100
# 18/18 - 10s - loss: 1.5130 - accuracy: 0.4106 - val_loss: 1.6152 - val_accuracy: 0.3845 - 10s/epoch - 559ms/step
# Epoch 68/100
# 18/18 - 10s - loss: 1.5110 - accuracy: 0.4131 - val_loss: 1.6130 - val_accuracy: 0.3810 - 10s/epoch - 543ms/step
# Epoch 69/100
# 18/18 - 10s - loss: 1.5088 - accuracy: 0.4129 - val_loss: 1.6130 - val_accuracy: 0.3864 - 10s/epoch - 552ms/step
# Epoch 70/100
# 18/18 - 10s - loss: 1.5067 - accuracy: 0.4138 - val_loss: 1.6106 - val_accuracy: 0.3847 - 10s/epoch - 551ms/step
# Epoch 71/100
# 18/18 - 10s - loss: 1.5021 - accuracy: 0.4149 - val_loss: 1.6121 - val_accuracy: 0.3850 - 10s/epoch - 544ms/step
# Epoch 72/100
# 18/18 - 10s - loss: 1.4994 - accuracy: 0.4160 - val_loss: 1.6134 - val_accuracy: 0.3878 - 10s/epoch - 540ms/step
# Epoch 73/100
# 18/18 - 10s - loss: 1.4944 - accuracy: 0.4164 - val_loss: 1.6132 - val_accuracy: 0.3889 - 10s/epoch - 538ms/step
# Epoch 74/100
# 18/18 - 10s - loss: 1.4953 - accuracy: 0.4181 - val_loss: 1.6060 - val_accuracy: 0.3897 - 10s/epoch - 567ms/step
# Epoch 75/100
# 18/18 - 11s - loss: 1.4936 - accuracy: 0.4176 - val_loss: 1.6198 - val_accuracy: 0.3885 - 11s/epoch - 602ms/step
# Epoch 76/100
# 18/18 - 10s - loss: 1.4926 - accuracy: 0.4172 - val_loss: 1.6184 - val_accuracy: 0.3867 - 10s/epoch - 579ms/step
# Epoch 77/100
# 18/18 - 10s - loss: 1.4897 - accuracy: 0.4205 - val_loss: 1.6140 - val_accuracy: 0.3897 - 10s/epoch - 566ms/step
# Epoch 78/100
# 18/18 - 10s - loss: 1.4819 - accuracy: 0.4210 - val_loss: 1.6086 - val_accuracy: 0.3897 - 10s/epoch - 568ms/step
# Epoch 79/100
# 18/18 - 10s - loss: 1.4859 - accuracy: 0.4204 - val_loss: 1.6156 - val_accuracy: 0.3881 - 10s/epoch - 582ms/step
# 793.1668193340302

# %%
# Show simple version of performance
score1 = model.evaluate(X_train, y_train, verbose=0, batch_size=batch_size)
score2 = model.evaluate(X_valid, y_valid, verbose=0, batch_size=batch_size)
score3 = model.evaluate(X_test, y_test, verbose=0, batch_size=batch_size)
print(score1)
print(score2)
print(score3)
# Out:
# [1.4239071607589722, 0.4459090828895569]
# [1.6059846878051758, 0.38972726464271545]
# [1.6055033206939697, 0.3906181752681732]

# %%
# Show loss curves 
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Plot confusion matrix
test_Y_hat = model.predict(X_test, batch_size=batch_size)
conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])
for i in range(0,X_test.shape[0]):
    j = list(y_test[i,:]).index(1)
    k = int(np.argmax(test_Y_hat[i,:]))
    conf[j,k] = conf[j,k] + 1
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
plot_confusion_matrix(confnorm, labels=classes)
# Out:
# 22/22 [==============================] - 2s 96ms/step

# %%
# Get the test accuracy for different SNRs
acc = {}
acc_array=[]

snr_array=np.asarray(lbl)[:,1]
lb_temp = preprocessing.LabelBinarizer()
lb_temp.fit(snr_array)
temp_array=lb_temp.classes_
snr_label_array = []


snr_label_array.append(temp_array[6])
snr_label_array.append(temp_array[4])
snr_label_array.append(temp_array[3])
snr_label_array.append(temp_array[2])
snr_label_array.append(temp_array[1])
snr_label_array.append(temp_array[0])
snr_label_array.append(temp_array[9])
snr_label_array.append(temp_array[8])
snr_label_array.append(temp_array[7])
snr_label_array.append(temp_array[5])
snr_label_array.append(temp_array[10])
snr_label_array.append(temp_array[16])
snr_label_array.append(temp_array[17])
snr_label_array.append(temp_array[18])
snr_label_array.append(temp_array[19])
snr_label_array.append(temp_array[11])
snr_label_array.append(temp_array[12])
snr_label_array.append(temp_array[13])
snr_label_array.append(temp_array[14])
snr_label_array.append(temp_array[15])


#print(snr_label_array)
y_test_snr=snr_array[test_idx]



for snr in snr_label_array:
    test_X_i = X_test[np.where(y_test_snr==snr)]
    test_Y_i = y_test[np.where(y_test_snr==snr)]
    
    test_Y_i_hat = model.predict(test_X_i)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,test_X_i.shape[0]):
        j = list(test_Y_i[i,:]).index(1)
        k = int(np.argmax(test_Y_i_hat[i,:]))
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
    
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix "%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print("Overall Accuracy: ", cor / (cor+ncor),"for SNR,snr)
    acc[snr] = 1.0*cor/(cor+ncor)
    acc_array.append(1.0*cor/(cor+ncor))

print("Random Guess Accuracy:",1/11)
# Out:
# 174/174 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.09033764367816093 for SNR b'-20'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.09509034495345867 for SNR b'-18'
# 174/174 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.09700685178507032 for SNR b'-16'
# 171/171 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.10332845647403073 for SNR b'-14'
# 175/175 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.12993744414655942 for SNR b'-12'
# 170/170 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.19992643001655325 for SNR b'-10'
# 169/169 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.28476331360946744 for SNR b'-8'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.36999817284852915 for SNR b'-6'
# 175/175 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.4573323771961276 for SNR b'-4'
# 173/173 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.49691358024691357 for SNR b'-2'
# 171/171 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5444689452407203 for SNR b'0'
# 173/173 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5638606676342526 for SNR b'2'
# 171/171 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5419945105215005 for SNR b'4'
# 171/171 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5608145294441387 for SNR b'6'
# 174/174 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5507011866235167 for SNR b'8'
# 176/176 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5395977932016373 for SNR b'10'
# 172/172 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5350446022210086 for SNR b'12'
# 172/172 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5554140127388535 for SNR b'14'
# 172/172 [==============================] - 0s 2ms/step
# Overall Accuracy:  0.5496809480401094 for SNR b'16'
# 170/170 [==============================] - 0s 1ms/step
# Overall Accuracy:  0.5507754800590842 for SNR b'18'
# Random Guess Accuracy: 0.09090909090909091

# %%
print(acc_array)
# Out:
# [0.09033764367816093, 0.09509034495345867, 0.09700685178507032, 0.10332845647403073, 0.12993744414655942, 0.19992643001655325, 0.28476331360946744, 0.36999817284852915, 0.4573323771961276, 0.49691358024691357, 0.5444689452407203, 0.5638606676342526, 0.5419945105215005, 0.5608145294441387, 0.5507011866235167, 0.5395977932016373, 0.5350446022210086, 0.5554140127388535, 0.5496809480401094, 0.5507754800590842]

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), acc_array)

# %%
dr_01 = [0.08800287356321838, 0.09582040518342763, 0.09267940858276236, 0.10095098756400878, 0.13798033958891867, 0.21114585249218318, 0.28994082840236685, 0.35282294902247396, 0.4410182861240588, 0.4892883079157589, 0.5373024623300258, 0.5477140783744557, 0.5328453796889295, 0.5461383232434416, 0.5370370370370371, 0.5242925787506674, 0.5315856544693246, 0.5410373066424022, 0.539288969917958, 0.5430206794682423];
dr_04 = [0.08710488505747127, 0.09417776966599745, 0.09646592138478183, 0.1071689831748354, 0.1415549597855228, 0.22328489976089755, 0.2964127218934911, 0.377854924173214, 0.46360702760846184, 0.49546114742193176, 0.5316060271958839, 0.5235849056603774, 0.5141811527904849, 0.5268758026050266, 0.5203164329377922, 0.5082754938601175, 0.5104678681958856, 0.5266606005459509, 0.5223336371923427, 0.5254800590841949];
dr_06 = [0.08979885057471264, 0.09472531483847417, 0.09484313018391634, 0.08778346744696415, 0.09597855227882038, 0.14677211697627368, 0.17806952662721892, 0.2408185638589439, 0.36608103262818215, 0.42592592592592593, 0.4566335905916942, 0.46752539912917274, 0.4602012808783166, 0.4654191891396074, 0.47680690399137, 0.47339384232069764, 0.4705989441106863, 0.46824385805277524, 0.4725615314494075, 0.47488921713441656];

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), dr_01,label = 'dropout = 0.1')
plt.plot(np.arange(-20,20,2),dr_04,label = 'dropout = 0.4')
plt.plot(np.arange(-20,20,2),dr_06,label = 'dropout = 0.6')
plt.legend(loc="upper left")

# %%
bs_256 = [0.09051724137931035, 0.09472531483847417, 0.10187522538766679, 0.12088514996342356, 0.17229669347631815, 0.23597572190546257, 0.30122041420118345, 0.3789512150557281, 0.44030118321979206, 0.49691358024691357, 0.595553105475928, 0.6184687953555879, 0.5952424519670632, 0.603558980003669, 0.5963682128730673, 0.597793201637302, 0.5898416166029492, 0.600181983621474, 0.6020054694621696, 0.59102658788774];
bs_1024 = [0.08800287356321838, 0.09600292024091987, 0.09754778218535881, 0.11356986100950987, 0.16300268096514745, 0.22659554901600149, 0.2869822485207101, 0.3637858578476156, 0.4164575116529222, 0.4529774872912128, 0.5520029400955531, 0.5959724238026125, 0.5912168344007319, 0.5982388552559164, 0.6021215390147429, 0.592988076170137, 0.5911159657746222, 0.6036396724294814, 0.5963536918869644, 0.5917651403249631];
bs_5000 = [0.08800287356321838, 0.09582040518342763, 0.09267940858276236, 0.10095098756400878, 0.13798033958891867, 0.21114585249218318, 0.28994082840236685, 0.35282294902247396, 0.4410182861240588, 0.4892883079157589, 0.5373024623300258, 0.5477140783744557, 0.5328453796889295, 0.5461383232434416, 0.5370370370370371, 0.5242925787506674, 0.5315856544693246, 0.5410373066424022, 0.539288969917958, 0.5430206794682423];

# %%
# Show loss curves 
plt.figure()
plt.title('Accuracy vs SNRs')
plt.grid(linestyle="-", color='grey')
plt.plot(np.arange(-20,20,2), bs_256,label = 'Batch size = 256')
plt.plot(np.arange(-20,20,2),bs_1024,label = 'Batch size = 1024')
plt.plot(np.arange(-20,20,2),bs_5000,label = 'Batch size = 5000')
plt.legend(loc="upper left")
